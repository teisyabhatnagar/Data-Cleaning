# %%
import pandas as pd
import numpy as np

# %%
ice_cream=["strawberry","choco","vanilla","cookies"]

# %%
pd.Series(ice_cream)
# Out:
# 0    strawberry
# 1         choco
# 2       vanilla
# 3       cookies
# dtype: object

# %%
lotter_number=[12,45,67,89,9]
pd.Series(lotter_number)
# Out:
# 0    12
# 1    45
# 2    67
# 3    89
# 4     9
# dtype: int64

# %%
#datatype is integer now because it has numbers

# %%
deci=[1.2,3.4,3.3,5.5]
pd.Series(deci)
# Out:
# 0    1.2
# 1    3.4
# 2    3.3
# 3    5.5
# dtype: float64

# %%
#datatype now is float because it has decimals

# %%
sushi={"salmon":"orange","tuna":"red","eel":"brown"}
pd.Series(sushi)
# Out:
# salmon    orange
# tuna         red
# eel        brown
# dtype: object

# %%
#this series was through dictionary

# %%
#now the use of methods.

# %%
price=pd.Series([23.5,45,78,2,5]) #this is a function

# %%
price
# Out:
# 0    23.5
# 1    45.0
# 2    78.0
# 3     2.0
# 4     5.0
# dtype: float64

# %%
price.sum()
# Out:
# 153.5

# %%
price.mean()
# Out:
# 30.7

# %%
price.std()
# Out:
# 31.53490129998824

# %%
adjectives=pd.Series(["beautiful","smart","intelligent","handsome","smart"])
adjectives
# Out:
# 0      beautiful
# 1          smart
# 2    intelligent
# 3       handsome
# 4          smart
# dtype: object

# %%
adjectives.size #this is an attribute and cant be used as function so u dont use round brackets
# Out:
# 5

# %%
adjectives.values
# Out:
# array(['beautiful', 'smart', 'intelligent', 'handsome', 'smart'],
#       dtype=object)

# %%
adjectives.is_unique #because "smart" is repeated twice so not all values are unique therefore its false
# Out:
# False

# %%
type(adjectives.values) #this is numpy array not pandas array
# Out:
# numpy.ndarray

# %%
weekdays=["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
fruits=["apple","grape","watermelon","guava","kiwi","litchi","mango"]

# %%
pd.Series(weekdays,fruits)
# Out:
# apple            monday
# grape           tuesday
# watermelon    wednesday
# guava          thursday
# kiwi             friday
# litchi         saturday
# mango            sunday
# dtype: object

# %%
pd.Series(fruits,weekdays)
# Out:
# monday            apple
# tuesday           grape
# wednesday    watermelon
# thursday          guava
# friday             kiwi
# saturday         litchi
# sunday            mango
# dtype: object

# %%
pd.Series(index=fruits,data=weekdays)
# Out:
# apple            monday
# grape           tuesday
# watermelon    wednesday
# guava          thursday
# kiwi             friday
# litchi         saturday
# mango            sunday
# dtype: object

# %%
weekdays=["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
fruits=["apple","grape","watermelon","guava","kiwi","litchi","mango"]

# %%
import numpy as np
import pandas as pd
pd.Series(weekdays,fruits)
# Out:
# apple            monday
# grape           tuesday
# watermelon    wednesday
# guava          thursday
# kiwi             friday
# litchi         saturday
# mango            sunday
# dtype: object

# %%
pd.Series(fruits,weekdays)
# Out:
# monday            apple
# tuesday           grape
# wednesday    watermelon
# thursday          guava
# friday             kiwi
# saturday         litchi
# sunday            mango
# dtype: object

# %%
a=pd.Series(index=weekdays,data=fruits)
a
# Out:
# monday            apple
# tuesday           grape
# wednesday    watermelon
# thursday          guava
# friday             kiwi
# saturday         litchi
# sunday            mango
# dtype: object

# %%
type(a.values)
# Out:
# numpy.ndarray

# %%
a.is_unique
# Out:
# True

# %%
a.sum()
# Out:
# 'applegrapewatermelonguavakiwilitchimango'

# %%
a.size
# Out:
# 7

# %%
a.min()
# Out:
# 'apple'

# %%
a.max()
# Out:
# 'watermelon'

# %%
sorted(a)
# Out:
# ['apple', 'grape', 'guava', 'kiwi', 'litchi', 'mango', 'watermelon']

# %%
len(a)
# Out:
# 7
