# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("/Users/teisya/Desktop/nba.csv")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba=pd.read_csv("/Users/teisya/Desktop/nba.csv")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna() #drops all rows which is bad
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how="all") #droppped row when all values in tht row are N/A
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College"]) #drops rows tht are na in college
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#use dropna subset instead of dropping generically based on wt question is asking

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.Salary=nba.Salary.fillna(0) #fills salary na values with na

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.College=nba.College.fillna("Unknown")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   592 non-null    object
#  6   Salary    592 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %%
#Filtering

# %%
nba.loc[:,["Name","Team","Position"]].head()  #: means go through the dataset, it is important for filtering
# Out:
#                 Name           Team Position
# 0         Saddiq Bey  Atlanta Hawks        F
# 1  Bogdan Bogdanovic  Atlanta Hawks        G
# 2        Kobe Bufkin  Atlanta Hawks        G
# 3       Clint Capela  Atlanta Hawks        C
# 4     Bruno Fernando  Atlanta Hawks      F-C

# %%
nba[["Name","Team","Position"]] #Not useful for filtering
# Out:
#                   Name                Team Position
# 0           Saddiq Bey       Atlanta Hawks        F
# 1    Bogdan Bogdanovic       Atlanta Hawks        G
# 2          Kobe Bufkin       Atlanta Hawks        G
# 3         Clint Capela       Atlanta Hawks        C
# 4       Bruno Fernando       Atlanta Hawks      F-C
# ..                 ...                 ...      ...
# 587       Ryan Rollins  Washington Wizards        G
# 588      Landry Shamet  Washington Wizards        G
# 589   Tristan Vukcevic  Washington Wizards        F
# 590       Delon Wright  Washington Wizards        G
# 591                NaN                 NaN      NaN
#
# [592 rows x 3 columns]

# %%
#Advanced Filtering/Condition

# %%
nba.loc[nba["Position"]=="G",["Name","Team","Position"]] #gives position that is only G
# Out:
#                   Name                Team Position
# 1    Bogdan Bogdanovic       Atlanta Hawks        G
# 2          Kobe Bufkin       Atlanta Hawks        G
# 5        Trent Forrest       Atlanta Hawks        G
# 10          Seth Lundy       Atlanta Hawks        G
# 11    Garrison Mathews       Atlanta Hawks        G
# ..                 ...                 ...      ...
# 584      Kendrick Nunn  Washington Wizards        G
# 586       Jordan Poole  Washington Wizards        G
# 587       Ryan Rollins  Washington Wizards        G
# 588      Landry Shamet  Washington Wizards        G
# 590       Delon Wright  Washington Wizards        G
#
# [229 rows x 3 columns]

# %%
nba.loc[nba["Position"]=="F",["Name","Team","Position"]]
# Out:
#                  Name                Team Position
# 0          Saddiq Bey       Atlanta Hawks        F
# 6          AJ Griffin       Atlanta Hawks        F
# 7      Mouhamed Gueye       Atlanta Hawks        F
# 9       Jalen Johnson       Atlanta Hawks        F
# 18      Dalano Banton      Boston Celtics        F
# ..                ...                 ...      ...
# 579      Anthony Gill  Washington Wizards        F
# 581     Corey Kispert  Washington Wizards        F
# 582        Kyle Kuzma  Washington Wizards        F
# 585    Eugene Omoruyi  Washington Wizards        F
# 589  Tristan Vukcevic  Washington Wizards        F
#
# [187 rows x 3 columns]

# %%
#Adding a column/changing it to 5% increment

# %%
nba["Salary_In"]=nba["Salary"]*1.05 #broadcasting function

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary    Salary_In
# 0        Villanova   4556983.0   4784832.15
# 1       Fenerbahce  18700000.0  19635000.00
# ...

# %%
#create new dataframe table using dataframe

# %%
Table={"Name":["Teisya",np.nan,"Rain",np.nan,"Power"],"Register":[1,2,3,4,5],"Class":["A",np.nan,"B","C","D"],"Score":[78,12,56,65,30]}

# %%
Table
# Out:
# {'Name': ['Teisya', nan, 'Rain', nan, 'Power'],
#  'Register': [1, 2, 3, 4, 5],
#  'Class': ['A', nan, 'B', 'C', 'D'],
#  'Score': [78, 12, 56, 65, 30]}

# %%
df=pd.DataFrame(Table)

# %%
df
# Out:
#      Name  Register Class  Score
# 0  Teisya         1     A     78
# 1     NaN         2   NaN     12
# 2    Rain         3     B     56
# 3     NaN         4     C     65
# 4   Power         5     D     30

# %%
New=df

# %%
New
# Out:
#      Name  Register Class  Score
# 0  Teisya         1     A     78
# 1     NaN         2   NaN     12
# 2    Rain         3     B     56
# 3     NaN         4     C     65
# 4   Power         5     D     30

# %%
New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Register  5 non-null      int64
#  2   Class     4 non-null      object
#  3   Score     5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
nba.iloc[:10,3] #iloc is index
# Out:
# 0     6-7
# 1     6-5
# 2     6-5
# 3    6-10
# 4    6-10
# 5     6-4
# 6     6-6
# 7    6-11
# 8     6-8
# 9     6-8
# Name: Height, dtype: object

# %%
nba[(nba["Salary"]>4000000) & (nba["Salary"]<5500000)]
# Out:
#                          Name                    Team Position Height  Weight  \
# 0                  Saddiq Bey           Atlanta Hawks        F    6-7   215.0
# 2                 Kobe Bufkin           Atlanta Hawks        G    6-5   195.0
# 30           Payton Pritchard          Boston Celtics        G    6-1   195.0
# 56            James Bouknight       Charlotte Hornets        G    6-4   190.0
# 115                Josh Green        Dallas Mavericks        G    6-7   200.0
# 144            Reggie Jackson          Denver Nuggets        G    6-2   208.0
# 149                Zeke Nnaji          Denver Nuggets      F-C    6-9   240.0
# 162               Jalen Duren         Detroit Pistons        C   6-11   250.0
# 171            Isaiah Stewart         Detroit Pistons      F-C    6-8   250.0
# 225               Jalen Smith          Indiana Pacers      F-C    6-9   215.0
# 247             Mason Plumlee    Los Angeles Clippers      F-C    7-0   254.0
# ...

# %%
#groupby

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("/Users/teisya/Desktop/fortune1000.csv")
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry  Revenue  Profits  Employees
# 0                       General Merchandisers   482130    14694    2300000
# ...

# %%
fortune=pd.read_csv("/Users/teisya/Desktop/fortune1000.csv",index_col="Rank")

# %%
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
df=pd.DataFrame(fortune)

# %%
df.groupby("Sector")["Profits"].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -73447
# Engineering & Construction        5304
# Financials                      260209
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
#an alternate is:

# %%
sectors=fortune.groupby("Sector")

# %%
sectors

# %%
#how to find out how many total sectors

# %%
len(sectors) #use len function to fin total of how many sectors are there
# Out:
# 21

# %%
#21 total sectors are there in the dataset

# %%
sectors.size() #size of the sector sectorwise using size funtion
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectors.first() #sectors in first provides a whole table overview, first company is Boeing. In the dataset whatever is the first company in ytht sector
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
sectors.last() #company names are different here
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
#Nested loop

# %%
#Getgroup function- getgrop is a loop

# %%
sectors.get_group("Energy")["Profits"].sum()
# Out:
# -73447

# %%
sectors.get_group("Apparel")["Profits"].sum()
# Out:
# 8236

# %%
fortune.groupby(["Industry","Sector"])["Profits"].sum()
# Out:
# Industry                                       Sector
# Advertising, marketing                         Business Services       1549
# Aerospace and Defense                          Aerospace & Defense    28742
# Airlines                                       Transportation         23800
# Apparel                                        Apparel                 8236
# Automotive Retailing, Services                 Retailing               2550
#                                                                       ...
# Waste Management                               Business Services       1718
# Wholesalers: Diversified                       Wholesalers             5193
# Wholesalers: Electronics and Office Equipment  Wholesalers             1857
# Wholesalers: Food and Grocery                  Wholesalers             1166
# Wholesalers: Health Care                       Health Care             3361
# Name: Profits, Length: 79, dtype: int64

# %%
sectors.get_group("Energy") #groups all energy
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#       Revenue  Profits  Employees
# Rank
# 2      246204    16150      75600
# 14     131118     4587      61500
# ...

# %%
sectors["Revenue"].sum()  #sum of all revenues sectors
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
#sector and industry size

# %%
sectors.agg({"Employees":"sum","Profits":"sum"})  #aggregate gives the sum or mean or ur column
# Out:
#                               Employees  Profits
# Sector
# Aerospace & Defense              968057    28742
# Apparel                          346397     8236
# Business Services               1361050    28227
# Chemicals                        463651    22628
# Energy                          1188927   -73447
# Engineering & Construction       406708     5304
# Financials                      3359948   260209
# Food and Drug Stores            1395398    16759
# Food, Beverages & Tobacco       1211632    51417
# Health Care                     2678289   106114
# Hotels, Resturants & Leisure    2484245    20697
# Household Products               646038    14428
# Industrials                     1545229    20764
# Materials                        638123     4428
# Media                            550314    24347
# Motor Vehicles & Parts          1082560    25898
# Retailing                       6227629    47830
# Technology                      3578949   180473
# ...

# %%
#show output which index starts with something, show industry only retailing filtering

# %%
#rearrange and sort data in ascending or descending

# %%
#if employees are more is profits more or less

# %%
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
#company is retailing and in this the number are employees if its more than profit is high or low

# %%
sectors.get_group("Retailing")
# Out:
#                              Company     Sector                    Industry  \
# Rank
# 1                            Walmart  Retailing       General Merchandisers
# 15                            Costco  Retailing  Specialty Retailers: Other
# 28                        Home Depot  Retailing  Specialty Retailers: Other
# 38                            Target  Retailing       General Merchandisers
# 47                            Lowe’s  Retailing  Specialty Retailers: Other
# ...                              ...        ...                         ...
# 899   Sears Hometown & Outlet Stores  Retailing  Specialty Retailers: Other
# 922                        Outerwall  Retailing  Specialty Retailers: Other
# 937                          hhgregg  Retailing  Specialty Retailers: Other
# 940             Restoration Hardware  Retailing  Specialty Retailers: Other
# 973             99 Cents Only Stores  Retailing  Specialty Retailers: Other
#
#       Revenue  Profits  Employees
# Rank
# ...

# %%
#find the two companies in each sectors with most employees

# %%
def count(n:int):
    if n>50000:
        return(n)

# %%
#question: top two companies that have the highest profits in retail industry

# %%
def retail(df):
    r = sectors.get_group("Retailing")
    return r.loc[r["Profits"] > 10000, ["Company","Profits"]]


retail(df)
# Out:
#       Company  Profits
# Rank
# 1     Walmart    14694

# %%
def sal(df):
    s = sectors.get_group("Retailing")
    return s.nlargest(2, "Profits")[["Company","Profits"]]

sal(df)
# Out:
#          Company  Profits
# Rank
# 1        Walmart    14694
# 28    Home Depot     7009

# %%
def sal(df):
    s = sectors.get_group("Retailing")
    return s.loc[s["Profits"]>10000,["Company","Profits"]]

sal(df)
# Out:
#       Company  Profits
# Rank
# 1     Walmart    14694

# %%
sectors.get_group("Retailing")
# Out:
#                              Company     Sector                    Industry  \
# Rank
# 1                            Walmart  Retailing       General Merchandisers
# 15                            Costco  Retailing  Specialty Retailers: Other
# 28                        Home Depot  Retailing  Specialty Retailers: Other
# 38                            Target  Retailing       General Merchandisers
# 47                            Lowe’s  Retailing  Specialty Retailers: Other
# ...                              ...        ...                         ...
# 899   Sears Hometown & Outlet Stores  Retailing  Specialty Retailers: Other
# 922                        Outerwall  Retailing  Specialty Retailers: Other
# 937                          hhgregg  Retailing  Specialty Retailers: Other
# 940             Restoration Hardware  Retailing  Specialty Retailers: Other
# 973             99 Cents Only Stores  Retailing  Specialty Retailers: Other
#
#       Revenue  Profits  Employees
# Rank
# ...

# %%
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
def top_two_companies(df):
    # returns the 2 companies with the most employees
    return df.nlargest(2, "Employees")[["Sector","Company","Employees"]]

top_two_companies(df)
# Out:
#                             Sector     Company  Employees
# Rank
# 1                        Retailing     Walmart    2300000
# 218   Hotels, Resturants & Leisure  Yum Brands     505000

# %%
df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
def top(df):
    return df.nlargest(2,"Employees")[["Company","Employees"]]

top(df)
# Out:
#          Company  Employees
# Rank
# 1        Walmart    2300000
# 218   Yum Brands     505000

# %%
def top(df):
    s=df.groupby("Sector").get_group("Retailing")
    return s.nlargest(2,"Profits")[["Company","Profits"]]
top(df)
# Out:
#          Company  Profits
# Rank
# 1        Walmart    14694
# 28    Home Depot     7009

# %%
def top(df):
    s=df.groupby("Sector").get_group("Retailing")
    return s.loc[s["Profits"]>1000,["Profits","Company"]]
top(df)
# Out:
#       Profits         Company
# Rank
# 1       14694         Walmart
# 15       2377          Costco
# 28       7009      Home Depot
# 38       3363          Target
# 47       2546          Lowe’s
# 89       2278             TJX
# 103      1072          Macy’s
# 139      1165  Dollar General
# 234      1253        L Brands
# 237      1021     Ross Stores
# 280      1160        AutoZone

# %%
def top(df):
    return fortune.sort_values("Employees",ascending=False).head(2)[["Sector","Employees"]]
top(df)
# Out:
#                             Sector  Employees
# Rank
# 1                        Retailing    2300000
# 218   Hotels, Resturants & Leisure     505000

# %%
def top(df):
    s=fortune.groupby("Sector").get_group("Retailing")
    return s.sort_values("Profits",ascending=False).head(2)[["Profits","Company"]]

top(df)
# Out:
#       Profits     Company
# Rank
# 1       14694     Walmart
# 28       7009  Home Depot
