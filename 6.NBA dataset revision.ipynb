# %%
import pandas as pd
import numpy as np

# %%
nba=pd.read_csv("/Users/teisya/Desktop/nba.csv")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
DS=nba["Salary"]*2

# %%
DS
# Out:
# 0       9113966.0
# 1      37400000.0
# 2       8188488.0
# 3      41232000.0
# 4       5163044.0
#           ...
# 587     3439728.0
# 588    20500000.0
# 589           NaN
# 590    16390244.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba["Salary"]=nba["Salary"]

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba["DS"]=DS

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary          DS
# 0        Villanova   4556983.0   9113966.0
# 1       Fenerbahce  18700000.0  37400000.0
# ...

# %%
nba.sort_values("Position",ascending=True)
# Out:
#                 Name                 Team Position Height  Weight  \
# 98      Damian Jones  Cleveland Cavaliers        C   6-11   245.0
# 92     Jarrett Allen  Cleveland Cavaliers        C    6-9   243.0
# 89    Nikola Vucevic        Chicago Bulls        C   6-10   260.0
# 432         Mo Bamba   Philadelphia 76ers        C    7-0   231.0
# 435   Dewayne Dedmon   Philadelphia 76ers        C   6-10   245.0
# ..               ...                  ...      ...    ...     ...
# 138  Armaan Franklin       Denver Nuggets      NaN    NaN     NaN
# 299    Caleb Daniels           Miami Heat      NaN    NaN     NaN
# 541     Kevin Obanor      Toronto Raptors      NaN    6-8   235.0
# 564     Nick Ongenda            Utah Jazz      NaN    NaN     NaN
# 591              NaN                  NaN      NaN    NaN     NaN
#
#                  College      Salary          DS
# 98            Vanderbilt   2586665.0   5173330.0
# 92                 Texas  20000000.0  40000000.0
# ...

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary          DS
# 0        Villanova   4556983.0   9113966.0
# 1       Fenerbahce  18700000.0  37400000.0
# ...

# %%
nba["sport"]="football"

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary          DS     sport
# 0        Villanova   4556983.0   9113966.0  football
# 1       Fenerbahce  18700000.0  37400000.0  football
# ...

# %%
nba=pd.read_csv('/Users/teisya/Desktop/nba.csv',usecols=["Team","Position","Name"],index_col=["Name"])

# %%
nba
# Out:
#                                  Team Position
# Name
# Saddiq Bey              Atlanta Hawks        F
# Bogdan Bogdanovic       Atlanta Hawks        G
# Kobe Bufkin             Atlanta Hawks        G
# Clint Capela            Atlanta Hawks        C
# Bruno Fernando          Atlanta Hawks      F-C
# ...                               ...      ...
# Ryan Rollins       Washington Wizards        G
# Landry Shamet      Washington Wizards        G
# Tristan Vukcevic   Washington Wizards        F
# Delon Wright       Washington Wizards        G
# NaN                               NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba.sort_values("Team",ascending=True)
# Out:
#                                 Team Position
# Name
# Saddiq Bey             Atlanta Hawks        F
# Trae Young             Atlanta Hawks        G
# Onyeka Okongwu         Atlanta Hawks      F-C
# Miles Norris           Atlanta Hawks      NaN
# Dejounte Murray        Atlanta Hawks        G
# ...                              ...      ...
# Deni Avdija       Washington Wizards        F
# Tristan Vukcevic  Washington Wizards        F
# Anthony Gill      Washington Wizards        F
# Delon Wright      Washington Wizards        G
# NaN                              NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba
# Out:
#                                  Team Position
# Name
# Saddiq Bey              Atlanta Hawks        F
# Bogdan Bogdanovic       Atlanta Hawks        G
# Kobe Bufkin             Atlanta Hawks        G
# Clint Capela            Atlanta Hawks        C
# Bruno Fernando          Atlanta Hawks      F-C
# ...                               ...      ...
# Ryan Rollins       Washington Wizards        G
# Landry Shamet      Washington Wizards        G
# Tristan Vukcevic   Washington Wizards        F
# Delon Wright       Washington Wizards        G
# NaN                               NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba.sort_values(["Team","Position"],ascending=True)
# Out:
#                               Team Position
# Name
# Clint Capela         Atlanta Hawks        C
# Saddiq Bey           Atlanta Hawks        F
# AJ Griffin           Atlanta Hawks        F
# Mouhamed Gueye       Atlanta Hawks        F
# Jalen Johnson        Atlanta Hawks        F
# ...                            ...      ...
# Jordan Poole    Washington Wizards        G
# Ryan Rollins    Washington Wizards        G
# Landry Shamet   Washington Wizards        G
# Delon Wright    Washington Wizards        G
# NaN                            NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba
# Out:
#                                  Team Position
# Name
# Saddiq Bey              Atlanta Hawks        F
# Bogdan Bogdanovic       Atlanta Hawks        G
# Kobe Bufkin             Atlanta Hawks        G
# Clint Capela            Atlanta Hawks        C
# Bruno Fernando          Atlanta Hawks      F-C
# ...                               ...      ...
# Ryan Rollins       Washington Wizards        G
# Landry Shamet      Washington Wizards        G
# Tristan Vukcevic   Washington Wizards        F
# Delon Wright       Washington Wizards        G
# NaN                               NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba.sort_values(["Team","Position"],ascending=True)
# Out:
#                               Team Position
# Name
# Clint Capela         Atlanta Hawks        C
# Saddiq Bey           Atlanta Hawks        F
# AJ Griffin           Atlanta Hawks        F
# Mouhamed Gueye       Atlanta Hawks        F
# Jalen Johnson        Atlanta Hawks        F
# ...                            ...      ...
# Jordan Poole    Washington Wizards        G
# Ryan Rollins    Washington Wizards        G
# Landry Shamet   Washington Wizards        G
# Delon Wright    Washington Wizards        G
# NaN                            NaN      NaN
#
# [592 rows x 2 columns]

# %%
nba.sort_index(ascending=True)
# Out:
#                                  Team Position
# Name
# A.J. Lawson          Dallas Mavericks        G
# AJ Green              Milwaukee Bucks        G
# AJ Griffin              Atlanta Hawks        F
# Aaron Gordon           Denver Nuggets        F
# Aaron Holiday         Houston Rockets        G
# ...                               ...      ...
# Zach LaVine             Chicago Bulls        G
# Zeke Nnaji             Denver Nuggets      F-C
# Ziaire Williams     Memphis Grizzlies        F
# Zion Williamson  New Orleans Pelicans        F
# NaN                               NaN      NaN
#
# [592 rows x 2 columns]
